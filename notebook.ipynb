# %% [markdown]
# <a href="https://colab.research.google.com/github/TEBIAN/Cleaning-data-and-the-skies/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cleaning data and the skies
#
# ## 📖 Background
# Your are a data analyst at an environmental company. Your task is to evaluate ozone pollution across various regions.
#
# You’ve obtained data from the U.S. Environmental Protection Agency (EPA), containing daily ozone measurements at monitoring stations across California. However, like many real-world datasets, it’s far from clean: there are missing values, inconsistent formats, potential duplicates, and outliers.
#
# Before you can provide meaningful insights, you must clean and validate the data. Only then can you analyze it to uncover trends, identify high-risk regions, and assess where policy interventions are most urgently needed.

# %% [markdown]
# ## 💾 The data
# The data is a modified dataset from the U.S. Environmental Protection Agency ([EPA](https://www.epa.gov/outdoor-air-quality-data/download-daily-data)).
#
# #### Ozone contains the daily air quality summary statistics by monitor for the state of California for 2024. Each row contains the date and the air quality metrics per collection method and site
# - "Date" - the calendar date with which the air quality values are associated
# - "Source" - the data source: EPA's Air Quality System (AQS), or Airnow reports
# - "Site ID" - the id for the air monitoring site
# - "POC" - the id number for the monitor
# - "Daily Max 8-hour Ozone Concentration" - the highest 8-hour value of the day for ozone concentration
# - "Units" - parts per million by volume (ppm)
# - "Daily AQI Value" - the highest air quality index value for the day, telling how clean or polluted the air is (a value of 50 represents good air quality, while a value above 300 is hazardous)
# - "Local Site Name" - name of the monitoring site
# - "Daily Obs Count" - number of observations reported in that day
# - "Percent Complete" - indicates whether all expected samples were collected
# - "Method Code" - identifier for the collection method
# - "CBSA Code" - identifier for the core base statistical area (CBSA)
# - "CBSA Name" - name of the core base statistical area
# - "State FIPS Code" - identifier for the state
# - "State" - name of the state
# - "County FIPS Code" - identifer for the county
# - "County" - name of the county
# - "Site Latitude" - latitude coordinates of the site
# - "Site Longitude" - longitude coordinates of the side

# %% [markdown]
# ## 💪 Competition challenge
#
# Create a report that covers the following:
# 1. Your EDA and data cleaning process.
# 2. How does daily maximum 8-hour ozone concentration vary over time and regions?
# 3. Are there any areas that consistently show high ozone concentrations? Do different methods report different ozone levels?
# 4. Consider if urban activity (weekend vs. weekday) has any affect on ozone levels across different days.
# 5. Bonus: plot a geospatial heatmap showing any high ozone concentrations.

# %% [markdown]
# ## 🧑‍⚖️ Judging criteria
#
# | CATEGORY | WEIGHTING | DETAILS                                                              |
# |:---------|:----------|:---------------------------------------------------------------------|
# | **Recommendations** | 35%       | <ul><li>Clarity of recommendations - how clear and well presented the recommendation is.</li><li>Quality of recommendations - are appropriate analytical techniques used & are the conclusions valid?</li><li>Number of relevant insights found for the target audience.</li></ul>       |
# | **Storytelling**  | 35%       | <ul><li>How well the data and insights are connected to the recommendation.</li><li>How the narrative and whole report connects together.</li><li>Balancing making the report in-depth enough but also concise.</li></ul> |
# | **Visualizations** | 20% | <ul><li>Appropriateness of visualization used.</li><li>Clarity of insight from visualization.</li></ul> |
# | **Votes** | 10% | <ul><li>Up voting - most upvoted entries get the most points.</li></ul> |

# %% [markdown]
# ## ✅ Checklist before publishing into the competition
# - Rename your workspace to make it descriptive of your work. N.B. you should leave the notebook name as notebook.ipynb.
# - **Remove redundant cells** like the judging criteria, so the workbook is focused on your story.
# - Make sure the workbook reads well and explains how you found your insights.
# - Try to include an **executive summary** of your recommendations at the beginning.
# - Check that all the cells run without error

# %% [markdown]
# ## ⌛️ Time is ticking. Good luck!

# %% [markdown]
# ## Data cleaning process

# %%
#import nessesry libraries
import pandas as pd
import numpy as np

# %%
ozone = pd.read_csv('ozone.csv')
#ozone.head(40)
ozone.tail(30)
# Out:
#                     Date  Source   Site ID  POC  \
# 54729              /2024     AQS  60270002    1
# 54730         08/31/2024  AirNow  60010011    1
# 54731         12/11/2024     AQS  60190011    1
# 54732         08/27/2024     AQS  61010003    1
# 54733   November 29/2024     AQS  60731201    1
# 54734         10/17/2024  AirNow  60650009    1
# 54735         01/08/2024     AQS  60192009    1
# 54736              /2024     AQS  60719002    1
# 54737         03/15/2024     AQS  60290232    1
# 54738         10/08/2024     AQS  60372005    1
# 54739         08/27/2024     AQS  60710001    1
# 54740              /2024     AQS  60990006    1
# 54741         02/18/2024  AirNow  60650009    1
# 54742         06/22/2024     AQS  60190011    1
# 54743              /2024     AQS  60371302    1
# 54744     August 12/2024     AQS  60710001    1
# 54745  September 27/2024     AQS  60192009    1
# 54746              /2024     AQS  61090005    1
# 54747         05/13/2024  AirNow  60131004    1
# 54748    January 22/2024     AQS  60012001    1
# 54749         02/25/2024     AQS  60254003    1
# 54750         06/18/2024     AQS  60658001    1
# 54751         05/20/2024     AQS  60190500    1
# 54752         08/15/2024     AQS  60430006    1
# 54753         11/27/2024     AQS  60371701    1
# 54754         02/16/2024     AQS  60710005    1
# 54755     August 14/2024     AQS  60270101    1
# 54756       June 30/2024     AQS  60690002    1
# 54757              /2024     AQS  61072010    1
# 54758       July 22/2024     AQS  60611004    1
#
#        Daily Max 8-hour Ozone Concentration Units  Daily AQI Value  \
# 54729                                 0.055   ppm             51.0
# 54730                                 0.039   ppm             36.0
# 54731                                 0.019   ppm             18.0
# 54732                                 0.062   ppm             74.0
# 54733                                 0.024   ppm             22.0
# 54734                                 0.045   ppm             42.0
# 54735                                 0.026   ppm             24.0
# 54736                                 0.048   ppm              NaN
# 54737                                 0.042   ppm             39.0
# 54738                                 0.069   ppm             97.0
# 54739                                 0.068   ppm             93.0
# 54740                                 0.035   ppm             32.0
# 54741                                 0.042   ppm             39.0
# 54742                                 0.071   ppm            101.0
# 54743                                 0.033   ppm             31.0
# 54744                                 0.053   ppm             49.0
# 54745                                 0.053   ppm             49.0
# 54746                                 0.058   ppm             61.0
# 54747                                 0.039   ppm             36.0
# 54748                                 0.032   ppm             30.0
# 54749                                   NaN   ppm             42.0
# 54750                                 0.066   ppm             87.0
# 54751                                 0.061   ppm             71.0
# 54752                                 0.036   ppm             33.0
# 54753                                 0.023   ppm             21.0
# 54754                                 0.044   ppm             41.0
# 54755                                 0.057   ppm             58.0
# 54756                                   NaN   ppm             29.0
# 54757                                 0.058   ppm             61.0
# 54758                                   NaN   ppm             45.0
#
#                           Local Site Name  Daily Obs Count  Percent Complete  \
# 54729                          WMRC/NCORE               17             100.0
# 54730                        Oakland West               19              79.0
# 54731                    Fresno - Garland               17             100.0
# 54732                           Yuba City               17             100.0
# 54733                         Pala Airpad               17             100.0
# 54734                            Pechanga               24             100.0
# 54735                        Tranquillity               17             100.0
# 54736                      Joshua Tree NP               17             100.0
# 54737                             Oildale               17             100.0
# 54738                            Pasadena               17             100.0
# 54739                             Barstow               17             100.0
# 54740                             Turlock               17             100.0
# 54741                            Pechanga               24             100.0
# 54742                    Fresno - Garland               17             100.0
# 54743                             Compton               17             100.0
# 54744                             Barstow               17             100.0
# 54745                        Tranquillity             1000             100.0
# 54746              Sonora-Barretta Street               17             100.0
# 54747                           San Pablo               20              83.0
# 54748                             Hayward               17             100.0
# 54749                         Westmorland               17             100.0
# 54750                            Rubidoux               17             100.0
# 54751  Table Mountain Air Monitoring Site               17             100.0
# 54752                          Jerseydale               17             100.0
# 54753                              Pomona               17             100.0
# 54754                           Crestline               17             100.0
# 54755      Death Valley NP - Park Village               17             100.0
# 54756                           Hollister               17             100.0
# 54757                         Porterville               17             100.0
# 54758            Tahoe City-Fairway Drive               17             100.0
#
#        Method Code  CBSA Code                                CBSA Name  \
# 54729         47.0    13860.0                               Bishop, CA
# 54730          NaN    41860.0        San Francisco-Oakland-Hayward, CA
# 54731         87.0    23420.0                               Fresno, CA
# 54732         87.0    49700.0                            Yuba City, CA
# 54733         87.0    41740.0                   San Diego-Carlsbad, CA
# 54734          NaN    40140.0     Riverside-San Bernardino-Ontario, CA
# 54735        199.0    23420.0                               Fresno, CA
# 54736         47.0    40140.0     Riverside-San Bernardino-Ontario, CA
# 54737         87.0    12540.0                          Bakersfield, CA
# 54738         87.0    31080.0       Los Angeles-Long Beach-Anaheim, CA
# 54739         87.0    40140.0     Riverside-San Bernardino-Ontario, CA
# 54740         87.0    33700.0                              Modesto, CA
# 54741          NaN    40140.0     Riverside-San Bernardino-Ontario, CA
# 54742         87.0    23420.0                               Fresno, CA
# 54743         87.0    31080.0       Los Angeles-Long Beach-Anaheim, CA
# 54744         87.0    40140.0     Riverside-San Bernardino-Ontario, CA
# 54745        199.0    23420.0                               Fresno, CA
# 54746         87.0    43760.0                               Sonora, CA
# 54747          NaN    41860.0        San Francisco-Oakland-Hayward, CA
# 54748         47.0    41860.0        San Francisco-Oakland-Hayward, CA
# 54749         87.0    20940.0                            El Centro, CA
# 54750         87.0    40140.0     Riverside-San Bernardino-Ontario, CA
# 54751         87.0    23420.0                               Fresno, CA
# 54752         87.0        NaN                                      NaN
# 54753         87.0    31080.0       Los Angeles-Long Beach-Anaheim, CA
# 54754         87.0    40140.0     Riverside-San Bernardino-Ontario, CA
# 54755         87.0    13860.0                               Bishop, CA
# 54756         47.0    41940.0       San Jose-Sunnyvale-Santa Clara, CA
# 54757        199.0    47300.0                  Visalia-Porterville, CA
# 54758         87.0    40900.0  Sacramento--Roseville--Arden-Arcade, CA
#
#        County FIPS Code          County  Site Latitude  Site Longitude
# 54729                27            Inyo      37.360684     -118.330783
# 54730                 1         Alameda      37.814781     -122.282347
# 54731                19          Fresno      36.785380     -119.773210
# 54732               101          Sutter      39.138773     -121.618549
# 54733                73       San Diego      33.362593     -117.090230
# 54734                65       Riverside      33.447867     -117.088649
# 54735                19          Fresno      36.634225     -120.382331
# 54736                71  San Bernardino      34.069570     -116.388930
# 54737                29            Kern      35.438035     -119.016787
# 54738                37     Los Angeles      34.132600     -118.127200
# 54739                71  San Bernardino      34.894050     -117.024710
# 54740                99      Stanislaus      37.488317     -120.836008
# 54741                65       Riverside      33.447867     -117.088649
# 54742                19          Fresno      36.785380     -119.773210
# 54743                37     Los Angeles      33.901389     -118.205000
# 54744                71  San Bernardino      34.894050     -117.024710
# 54745                19          Fresno      36.634225     -120.382331
# 54746               109        Tuolumne      37.981780     -120.378551
# 54747                13    Contra Costa      37.960400     -122.356811
# 54748                 1         Alameda      37.654456     -122.031547
# 54749                25        Imperial      33.032500     -115.623610
# 54750                65       Riverside      33.999580     -117.416010
# 54751                19          Fresno      36.985119     -119.658339
# 54752                43        Mariposa      37.543770     -119.839570
# 54753                37     Los Angeles      34.067030     -117.751400
# 54754                71  San Bernardino      34.243100     -117.272350
# 54755                27            Inyo      36.508611     -116.847778
# 54756                69      San Benito      36.843425     -121.362100
# 54757               107          Tulare      36.031831     -119.055018
# 54758                61          Placer      39.166017     -120.148833

# %% [markdown]
# ### Define helping function

# %%
def show_analysis(df, max_unique=20, show_counts=False, sample_size=10):
    """
    Display analysis and unique values for each column in a DataFrame with sampling for high-cardinality columns.

    Parameters:
    - df: pandas DataFrame
    - max_unique: maximum number of unique values to display fully (default: 20)
    - show_counts: whether to show count of each unique value (default: False)
    - sample_size: number of samples to show when there are too many unique values (default: 5)
    """
    print("Display the number of rows then columns in dataframe:{}\n".format(df.shape))
    print("*"*60)
    print("Describe statistic for each column in dataframe:\n{}\n".format(df.describe()))
    print("*"*60)
    print("Summary of the dataframe:\n")
    print(format(df.info()))
    print(f"\n{'='*60}")
    print(f"UNIQUE VALUES ANALYSIS: {len(df)} rows × {len(df.columns)} columns")
    print(f"{'='*60}\n")

    for col in df.columns:
        unique_count = df[col].nunique(dropna=False)
        dtype = df[col].dtype
        na_count = df[col].isna().sum()

        print(f"➤ Column: {col} ({dtype})")
        print(f"   Unique values: {unique_count:,}{f' (NA: {na_count:,})' if na_count > 0 else ''}")

        if unique_count == 0:
            print("   No values found\n")
            continue

        if unique_count <= max_unique:
            if show_counts:
                print(df[col].value_counts(dropna=False).to_string())
            else:
                print("   Values:", df[col].unique())
        else:
            sample = df[col].dropna().sample(min(sample_size, unique_count),
                              random_state=1).unique()
            print(f"   Sample of {min(sample_size, unique_count)} values:", sample)
            print(f"   [Showing {sample_size} of {unique_count:,} unique values]")

        print("-"*60)

# %%
# Clean date column
from datetime import datetime
def clean_date(date_str):
    """
    Clean and parse various date formats into datetime objects, then format as 'MM DD YYYY'.

    Handles formats like:
    - MM/DD/YYYY
    - Month DD/YYYY
    - /YYY
    """
    try:
        # Handle cases like "/2024" - mark as invalid
        if date_str.startswith('/'):
            return np.nan
        # Handle cases like "January 04/2024"
        if '/' in date_str and ' ' in date_str:
            month, rest = date_str.split(' ')
            day, year = rest.split('/')
            date_obj = datetime.strptime(f"{month} {day}, {year}", "%B %d, %Y")
            return date_obj.strftime("%m %d %Y")
        # Handle standard format "01/02/2024" (MM/DD/YYYY)
        if '/' in date_str:
            date_obj = datetime.strptime(date_str, "%m/%d/%Y")
            return date_obj.strftime("%m %d %Y")
    except (ValueError, AttributeError, IndexError):
        return np.nan

# %% [markdown]
#  EDA and data cleaning process

# %%
show_analysis(ozone)
# Out:
# Display the number of rows then columns in dataframe:(45557, 18)
#
# ************************************************************
# Describe statistic for each column in dataframe:
#             Site ID           POC  Daily Max 8-hour Ozone Concentration  \
# count  4.555700e+04  45557.000000                          43306.000000
# mean   6.059057e+07      1.000285                              0.043530
# std    2.999208e+05      0.016890                              0.014641
# min    6.001001e+07      1.000000                              0.000000
# 25%    6.031100e+07      1.000000                              0.034000
# 50%    6.065500e+07      1.000000                              0.041000
# 75%    6.079801e+07      1.000000                              0.052000
# max    6.113100e+07      2.000000                              0.131000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete   Method Code  \
# count     43236.000000     45557.000000      45557.000000  40109.000000
# mean         45.302965        27.435542         99.330180     88.994365
# std          25.928420        97.277666          3.678108     36.552623
# min           0.000000         1.000000          6.000000     47.000000
# 25%          31.000000        17.000000        100.000000     87.000000
# 50%          38.000000        17.000000        100.000000     87.000000
# 75%          48.000000        17.000000        100.000000     87.000000
# max         227.000000      1000.000000        100.000000    199.000000
#
#           CBSA Code  County FIPS Code  Site Latitude  Site Longitude
# count  43555.000000      45557.000000   45557.000000    45557.000000
# mean   36140.547354         58.889150      36.168004     -119.662776
# std     9513.658657         29.985174       2.193970        2.025995
# min    12540.000000          1.000000      32.578165     -124.179490
# 25%    31080.000000         31.000000      34.181977     -121.420838
# 50%    40140.000000         65.000000      36.209286     -119.828400
# 75%    41860.000000         79.000000      37.961578     -118.068500
# max    49700.000000        113.000000      41.726892     -114.602090
#
# ************************************************************
# Summary of the dataframe:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 45557 entries, 11110 to 26790
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  45557 non-null  object
#  1   Source                                45557 non-null  object
#  2   Site ID                               45557 non-null  int64
#  3   POC                                   45557 non-null  int64
#  4   Daily Max 8-hour Ozone Concentration  43306 non-null  float64
#  5   Units                                 45557 non-null  object
#  6   Daily AQI Value                       43236 non-null  float64
#  7   Local Site Name                       45557 non-null  object
#  8   Daily Obs Count                       45557 non-null  int64
#  9   Percent Complete                      45557 non-null  float64
#  10  Method Code                           40109 non-null  float64
#  11  CBSA Code                             43555 non-null  float64
#  12  CBSA Name                             43555 non-null  object
#  13  County FIPS Code                      45557 non-null  int64
#  14  County                                45557 non-null  object
#  15  Site Latitude                         45557 non-null  float64
#  16  Site Longitude                        45557 non-null  float64
#  17  clean_date                            45557 non-null  object
# dtypes: float64(7), int64(4), object(7)
# memory usage: 7.6+ MB
# None
#
# ============================================================
# UNIQUE VALUES ANALYSIS: 45557 rows × 18 columns
# ============================================================
#
# ➤ Column: Date (object)
#    Unique values: 732
#    Sample of 10 values: ['10/29/2024' '03/03/2024' '03/04/2024' '05/20/2024' '03/20/2024'
#  '12/07/2024' '03/13/2024' '10/09/2024' '09/28/2024' '07/11/2024']
#    [Showing 10 of 732 unique values]
# ------------------------------------------------------------
# ➤ Column: Source (object)
#    Unique values: 2
#    Values: ['AQS' 'AirNow']
# ------------------------------------------------------------
# ➤ Column: Site ID (int64)
#    Unique values: 162
#    Sample of 10 values: [60010011 60590007 60090001 60210003 60131002 61130004 60731201 60611004
#  60731022 60790005]
#    [Showing 10 of 162 unique values]
# ------------------------------------------------------------
# ➤ Column: POC (int64)
#    Unique values: 2
#    Values: [1 2]
# ------------------------------------------------------------
# ➤ Column: Daily Max 8-hour Ozone Concentration (float64)
#    Unique values: 123 (NA: 2,251)
#    Sample of 10 values: [0.034 0.05  0.033 0.03  0.047 0.079 0.005 0.042 0.061 0.027]
#    [Showing 10 of 123 unique values]
# ------------------------------------------------------------
# ➤ Column: Units (object)
#    Unique values: 1
#    Values: ['ppm']
# ------------------------------------------------------------
# ➤ Column: Daily AQI Value (float64)
#    Unique values: 119 (NA: 2,321)
#    Sample of 10 values: [ 35.  38.  42.  29. 100.  36.  40.  44.  31.  17.]
#    [Showing 10 of 119 unique values]
# ------------------------------------------------------------
# ➤ Column: Local Site Name (object)
#    Unique values: 162
#    Sample of 10 values: ['Oakland West' 'Anaheim' 'San Andreas-Gold Strike Road'
#  'Willows-Colusa Street' 'Bethel Island' 'Davis-UCD Campus' 'Pala Airpad'
#  'Tahoe City-Fairway Drive' 'El Cajon - Lexington Elementary School'
#  'Paso Robles']
#    [Showing 10 of 162 unique values]
# ------------------------------------------------------------
# ➤ Column: Daily Obs Count (int64)
#    Unique values: 24
#    Sample of 10 values: [24 17 23 13]
#    [Showing 10 of 24 unique values]
# ------------------------------------------------------------
# ➤ Column: Percent Complete (float64)
#    Unique values: 22
#    Sample of 10 values: [100.  96.  76.]
#    [Showing 10 of 22 unique values]
# ------------------------------------------------------------
# ➤ Column: Method Code (float64)
#    Unique values: 5 (NA: 5,448)
#    Values: [ 87. 199.  nan  47.  53.]
# ------------------------------------------------------------
# ➤ Column: CBSA Code (float64)
#    Unique values: 33 (NA: 2,002)
#    Sample of 10 values: [41940. 42200. 12540. 13860. 41860. 40900. 43760. 40140.]
#    [Showing 10 of 33 unique values]
# ------------------------------------------------------------
# ➤ Column: CBSA Name (object)
#    Unique values: 33 (NA: 2,002)
#    Sample of 10 values: ['San Jose-Sunnyvale-Santa Clara, CA' 'Santa Maria-Santa Barbara, CA'
#  'Bakersfield, CA' 'Bishop, CA' 'San Francisco-Oakland-Hayward, CA'
#  'Sacramento--Roseville--Arden-Arcade, CA' 'Sonora, CA'
#  'Riverside-San Bernardino-Ontario, CA']
#    [Showing 10 of 33 unique values]
# ------------------------------------------------------------
# ➤ Column: County FIPS Code (int64)
#    Unique values: 48
#    Sample of 10 values: [  1  59   9  21  13 113  73  61  79]
#    [Showing 10 of 48 unique values]
# ------------------------------------------------------------
# ➤ Column: County (object)
#    Unique values: 50
#    Sample of 10 values: ['Alameda' 'Orange' 'Calaveras' 'Glenn' 'Contra Costa' 'Yolo' 'San Diego'
#  'Placer' 'San Luis Obispo']
#    [Showing 10 of 50 unique values]
# ------------------------------------------------------------
# ➤ Column: Site Latitude (float64)
#    Unique values: 162
#    Sample of 10 values: [37.814781   33.83062    38.20185    39.53387    38.006311   38.53445
#  33.36259283 39.16601667 32.789565   35.614668  ]
#    [Showing 10 of 162 unique values]
# ------------------------------------------------------------
# ➤ Column: Site Longitude (float64)
#    Unique values: 162
#    Sample of 10 values: [-122.282347   -117.93845    -120.680277   -122.190834   -121.641918
#  -121.7734     -117.09023    -120.14883333 -116.944308   -120.656912  ]
#    [Showing 10 of 162 unique values]
# ------------------------------------------------------------
# ➤ Column: clean_date (object)
#    Unique values: 366
#    Sample of 10 values: ['10 29 2024' '03 03 2024' '03 04 2024' '05 20 2024' '03 20 2024'
#  '12 07 2024' '03 13 2024' '10 09 2024' '09 28 2024' '07 11 2024']
#    [Showing 10 of 366 unique values]
# ------------------------------------------------------------

# %%
#clean and sort date column
ozone['clean_date']=ozone['Date'].apply(clean_date)
ozone = ozone.dropna(subset=['clean_date']).sort_values('clean_date')
ozone.head()
# Out:
#                   Date Source   Site ID  POC  \
# 11110       01/01/2024    AQS  60290014    1
# 38483       01/01/2024    AQS  60790005    1
# 19877  January 01/2024    AQS  60450008    1
# 13596       01/01/2024    AQS  60333002    1
# 9754   January 01/2024    AQS  60270101    1
#
#        Daily Max 8-hour Ozone Concentration Units  Daily AQI Value  \
# 11110                                 0.025   ppm              NaN
# 38483                                 0.033   ppm             31.0
# 19877                                 0.018   ppm             17.0
# 13596                                 0.022   ppm             20.0
# 9754                                  0.036   ppm             33.0
#
#                       Local Site Name  Daily Obs Count  Percent Complete  \
# 11110          Bakersfield-California               17             100.0
# 38483                     Paso Robles               17             100.0
# 19877              Ukiah-Gobbi Street               17             100.0
# 13596         Lakeport-S. Main Street               17             100.0
# 9754   Death Valley NP - Park Village               17             100.0
#
#        Method Code  CBSA Code                                      CBSA Name  \
# 11110         87.0    12540.0                                Bakersfield, CA
# 38483         87.0    42020.0  San Luis Obispo-Paso Robles-Arroyo Grande, CA
# 19877        199.0    46380.0                                      Ukiah, CA
# 13596         87.0    17340.0                                  Clearlake, CA
# 9754          87.0    13860.0                                     Bishop, CA
#
#        County FIPS Code           County  Site Latitude  Site Longitude  \
# 11110                29             Kern      35.356615     -119.062613
# 38483                79  San Luis Obispo      35.614668     -120.656912
# 19877                45        Mendocino      39.145660     -123.202980
# 13596                33             Lake      39.018930     -122.913330
# 9754                 27             Inyo      36.508611     -116.847778
#
#        clean_date
# 11110  01 01 2024
# 38483  01 01 2024
# 19877  01 01 2024
# 13596  01 01 2024
# 9754   01 01 2024

# %%
# clean Daily max 8-hour ozone Concentration by Convert empty strings to NaN
ozone['Daily Max 8-hour Ozone Concentration'] = ozone['Daily Max 8-hour Ozone Concentration'].replace('', np.nan)
